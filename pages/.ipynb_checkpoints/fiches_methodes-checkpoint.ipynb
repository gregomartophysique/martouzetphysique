# %% [raw]
# ---
# title: "Fiches méthode"
# format: html
# ---

# %% [markdown]
# Cette page regroupe des fiches méthodes destinées aux étudiants de PCSI.

# %% [markdown]
# - [Fiche A - Formulaire mathématiques](pdf/A-formulaire_maths.pdf)
# - [Fiche B - Signaux et déphasage](pdf/B-Signaux_déphasage.pdf)
# - [Fiche C - Dévellopements limités](pdf/C-DL.pdf)
# - [Fiche D - Surface et volumes élémentaires](pdf/D-surface_volume.pdf)
# - [Fiche F - Produit scalaire](pdf/F-produit_scalaire.pdf)
